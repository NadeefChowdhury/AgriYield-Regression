# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/agriyield-2025/sample_submission.csv
# /kaggle/input/agriyield-2025/train.csv
# /kaggle/input/agriyield-2025/test.csv
# /kaggle/input/agriyield-2025/data_description.md

# %%
df = pd.read_csv('/kaggle/input/agriyield-2025/train.csv')

# %%
df.columns
# Out:
# Index(['field_id', 'soil_ph', 'organic_matter', 'sand_pct', 'temperature',
#        'humidity', 'rainfall', 'ndvi', 'yield'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['soil_ph', 'organic_matter', 'sand_pct', 'temperature',
       'humidity', 'rainfall', 'ndvi']]
y = df['yield']
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
#from sklearn.linear_model import Lasso

# %%
#from sklearn.linear_model import LassoCV
#lasso_cv = LassoCV(cv = 5)
#lasso_cv.fit(X_train, y_train)
#best_alpha = lasso_cv.alpha_
#print(best_alpha)
# Out:
# 6.00636824992873

# %%
#lasso = Lasso(alpha=6.006)
#lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=6.006)

# %%
#predictions = lasso.predict(X_test)

# %%
#from sklearn.metrics import mean_squared_error, mean_absolute_error
#import math

# %%
#print('Mean Absolute Error:',mean_absolute_error(y_test, predictions))
#print('Mean Squared Error:',mean_squared_error(y_test, predictions))
#print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 384.7381316529222
# Mean Squared Error: 193521.03988760666
# Root Mean Squared Error: 439.91026344881595

# %%
#predictions_cv = lasso_cv.predict(X_test)

# %%
#print('Mean Absolute Error:',mean_absolute_error(y_test, predictions_cv))
#print('Mean Squared Error:',mean_squared_error(y_test, predictions_cv))
#print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, predictions_cv)))
# Out:
# Mean Absolute Error: 384.7381310558528
# Mean Squared Error: 193521.03704106304
# Root Mean Squared Error: 439.91026021344743

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

scaler = MinMaxScaler()
standardScaler = StandardScaler()

# %%
X = scaler.fit_transform(X)
#X_test = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LassoCV
lasso_cv = LassoCV(cv = 5)
lasso_cv.fit(X, y)
best_alpha = lasso_cv.alpha_
print(best_alpha)
# Out:
# 2.1306273357500007

# %%
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, y)
# Out:
# Lasso(alpha=2.1306273357500007)

# %%
df_test = pd.read_csv('/kaggle/input/agriyield-2025/test.csv')
X_test = df_test[['soil_ph', 'organic_matter', 'sand_pct', 'temperature',
       'humidity', 'rainfall', 'ndvi']]
X_test = scaler.fit_transform(X_test)

# %%
predictions = lasso.predict(X_test)

# %% [raw]
# predictions

# %%
predictions
# Out:
# array([4251.9764, 4251.9764, 4251.9764, ..., 4251.9764, 4251.9764,
#        4251.9764])

# %%
field_id = df_test['field_id']

# %%
data = {
    'field_id':field_id,
    'yield':predictions
}

# %%
submission_df = pd.DataFrame(data)

# %%
submission_df
# Out:
#      field_id      yield
# 0      T00001  4251.9764
# 1      T00002  4251.9764
# 2      T00003  4251.9764
# 3      T00004  4251.9764
# 4      T00005  4251.9764
# ...       ...        ...
# 1995   T01996  4251.9764
# 1996   T01997  4251.9764
# 1997   T01998  4251.9764
# 1998   T01999  4251.9764
# 1999   T02000  4251.9764
#
# [2000 rows x 2 columns]

# %%
print('Mean Absolute Error:',mean_absolute_error(y_test, predictions))
print('Mean Squared Error:',mean_squared_error(y_test, predictions))
print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 384.8092651856257
# Mean Squared Error: 193553.45176205607
# Root Mean Squared Error: 439.947101095184

# %%
predictions_cv = lasso_cv.predict(X_test)

# %%
print('Mean Absolute Error:',mean_absolute_error(y_test, predictions_cv))
print('Mean Squared Error:',mean_squared_error(y_test, predictions_cv))
print('Root Mean Squared Error:',math.sqrt(mean_squared_error(y_test, predictions_cv)))
# Out:
# Mean Absolute Error: 384.8092651856257
# Mean Squared Error: 193553.45176205607
# Root Mean Squared Error: 439.947101095184
